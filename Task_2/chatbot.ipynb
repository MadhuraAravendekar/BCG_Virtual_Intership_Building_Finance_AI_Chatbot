# %% [markdown]
# ### The AI powered Financial Chatbot Prototype currently responds only to the given set of questions for selected companies and fiscal years wiz: --
# What is the total revenue?
#
# What is the Net Income?
#
# What is the sum of total assets?
#
# What is the sum of total liabilities?
#
# What is cash flow from operating activities?
#
# What is the revenue growth(%) ?
#
# What is the net income growth(%) ?
#
# What is the assets growth(%) ?
#
# What is the liabilities growth(%) ?
#
# What is the cash flow from operations growth(%) ?
#
# What is the year by year average revenue growth rate(%)?
#
# What is the year by year average net income growth rate(%)?
#
# What is the year by year average assets growth rate(%)?
#
# What is the year by year average liabilities growth rate(%)?
#
# What is the year by year average cash flow from operations growth rate(%)?

# %%
import pandas as pd
data = pd.read_csv('../Task_1/SEC_data_cleaned.csv')
data_2 = pd.read_csv('../Task_1/Summary_final_report.csv')

# %%
# %run AI_Prototype.py
# Out:
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# The sum of Total Assets for Apple for fiscal year 2024 is $ 512163000000
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# The sum of Total Assets for Tesla for fiscal year 2024 is $ 122070000000
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
# Invalid Company Name. Please check and enter correct company name by starting the chatbot session again

# %%
# %run AI_Prototype.py
# Out:
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# The sum of Total Assets for Microsoft for fiscal year 2024 is $ 364980000000
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# The Year By Year Average Assets Growth Rate(%) from 2021 to 2023 for Tesla is 9.1279(%)
# ----------------------------------------------------------------------------
# Enter 'Hi' Properly!!!!! by starting the chatbot session again

# %%
# %run AI_Prototype.py
# Out:
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# Sorry, I cannot only provide information on the requested query.
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# Sorry, I cannot only provide information on the requested query.
# ----------------------------------------------------------------------------
# Enter 'Hi' Properly!!!!! by starting the chatbot session again

# %%
# %run AI_Prototype.py
# Out:
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# The Year By Year Average Liabilities Growth Rate(%) from 2021 to 2023 for Microsoft is -0.4181(%)
# ----------------------------------------------------------------------------
#
# Hello! Welcome to AI Driven Financial Chatbot!!!
#
# I can help you with your financial queries
# Please select the company name from below: -
#
# 1.Microsoft
# 2.Tesla
# 3.Apple
#
# The data for the fiscal year 2023, 2024, and 2025 is currently available
#
# Please enter your query
# The Year By Year Average Cash Flow from Operations Growth Rate(%) from 2021 to 2023 for Microsoft is 0.4163(%)
# ----------------------------------------------------------------------------
# Enter 'Hi' Properly!!!!! by starting the chatbot session again
